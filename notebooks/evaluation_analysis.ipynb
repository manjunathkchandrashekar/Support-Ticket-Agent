# %%
import os
import sys
sys.path.insert(0, os.path.abspath(".."))
from src.graph.support_graph import build_support_graph
from src.utils.helpers import load_json
from src.utils.schemas import Ticket
from src.evaluation.route_accuracy_eval import evaluate_route_accuracy from src.evaluation.groundedness_eval import evaluate_groundedness
graph = build_support_graph()
tickets = [Ticket (**t) for t in load_json("../data/tickets/synthetic_tickets.json")]
predicted routes = {}
groundedness_scores = 0
for ticket in tickets:
state = graph.invoke({"ticket": ticket}) predicted_routes[ticket.ticket_id]
I
state["route_decision"].route
groundedness_scores [ticket.ticket_id] evaluate_groundedness (state["rag_answer"])
evaluate_route_accuracy (predicted_routes, "../data/evaluation/expected_routes.json")
report = print(report)
